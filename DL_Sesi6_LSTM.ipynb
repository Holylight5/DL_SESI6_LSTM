# %%
import yfinance as yf

# Mengunduh data harga saham 
data = yf.download('INDY', start='2022-01-01', end='2022-12-01')
data.to_csv('INDY.csv')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM, Dense

# Membaca data saham dari file CSV
#jika menggunakan data selain saham yahoo finance, bisa ubah disini
data = pd.read_csv('INDY.csv')
data = data['Close'].values #cek pada masing2 data, karena terkadang atribut close = CLOSE/Close

# Normalisasi data
scaler = MinMaxScaler()
data = scaler.fit_transform(data.reshape(-1, 1))

# Fungsi untuk membagi dataset menjadi input dan output
def create_dataset(dataset, look_back=1):
    X, y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:(i+look_back)])
        y.append(dataset[i+look_back])
    return np.array(X), np.array(y)

# Membagi dataset menjadi data latih dan data uji
train_size = int(len(data) * 0.67)
train_data, test_data = data[0:train_size], data[train_size:]

look_back = 5
train_X, train_y = create_dataset(train_data, look_back)
test_X, test_y = create_dataset(test_data, look_back)

# Reshape data agar sesuai dengan input LSTM
train_X = np.reshape(train_X, (train_X.shape[0], 1, train_X.shape[1]))
test_X = np.reshape(test_X, (test_X.shape[0], 1, test_X.shape[1]))

# Membangun model LSTM
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Melatih model
model.fit(train_X, train_y, epochs=100, batch_size=1, verbose=2)

# Melakukan prediksi pada data uji
predicted = model.predict(test_X)
predicted = scaler.inverse_transform(predicted)
test_y = scaler.inverse_transform(test_y)

# Menghitung Mean Absolute Error (MAE)
mae = mean_absolute_error(test_y, predicted)
print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# Epoch 1/100
# 156/156 - 3s - loss: 0.1455 - 3s/epoch - 22ms/step
# Epoch 2/100
# 156/156 - 1s - loss: 0.0435 - 505ms/epoch - 3ms/step
# Epoch 3/100
# 156/156 - 1s - loss: 0.0218 - 507ms/epoch - 3ms/step
# Epoch 4/100
# 156/156 - 0s - loss: 0.0164 - 480ms/epoch - 3ms/step
# Epoch 5/100
# 156/156 - 1s - loss: 0.0126 - 619ms/epoch - 4ms/step
# Epoch 6/100
# 156/156 - 1s - loss: 0.0102 - 588ms/epoch - 4ms/step
# Epoch 7/100
# 156/156 - 1s - loss: 0.0085 - 567ms/epoch - 4ms/step
# Epoch 8/100
# 156/156 - 1s - loss: 0.0076 - 578ms/epoch - 4ms/step
# Epoch 9/100
# 156/156 - 1s - loss: 0.0069 - 584ms/epoch - 4ms/step
# Epoch 10/100
# 156/156 - 0s - loss: 0.0068 - 449ms/epoch - 3ms/step
# Epoch 11/100
# 156/156 - 1s - loss: 0.0066 - 526ms/epoch - 3ms/step
# Epoch 12/100
# 156/156 - 0s - loss: 0.0064 - 498ms/epoch - 3ms/step
# Epoch 13/100
# 156/156 - 1s - loss: 0.0061 - 575ms/epoch - 4ms/step
# Epoch 14/100
# 156/156 - 1s - loss: 0.0060 - 537ms/epoch - 3ms/step
# Epoch 15/100
# 156/156 - 1s - loss: 0.0060 - 586ms/epoch - 4ms/step
# Epoch 16/100
# 156/156 - 1s - loss: 0.0060 - 542ms/epoch - 3ms/step
# Epoch 17/100
# 156/156 - 1s - loss: 0.0058 - 566ms/epoch - 4ms/step
# Epoch 18/100
# 156/156 - 1s - loss: 0.0058 - 520ms/epoch - 3ms/step
# Epoch 19/100
# 156/156 - 1s - loss: 0.0056 - 505ms/epoch - 3ms/step
# Epoch 20/100
# 156/156 - 1s - loss: 0.0055 - 544ms/epoch - 3ms/step
# Epoch 21/100
# 156/156 - 0s - loss: 0.0055 - 388ms/epoch - 2ms/step
# Epoch 22/100
# 156/156 - 0s - loss: 0.0055 - 424ms/epoch - 3ms/step
# Epoch 23/100
# 156/156 - 0s - loss: 0.0053 - 354ms/epoch - 2ms/step
# Epoch 24/100
# 156/156 - 0s - loss: 0.0053 - 377ms/epoch - 2ms/step
# Epoch 25/100
# 156/156 - 0s - loss: 0.0052 - 349ms/epoch - 2ms/step
# Epoch 26/100
# 156/156 - 0s - loss: 0.0051 - 312ms/epoch - 2ms/step
# Epoch 27/100
# 156/156 - 1s - loss: 0.0051 - 531ms/epoch - 3ms/step
# Epoch 28/100
# 156/156 - 0s - loss: 0.0050 - 478ms/epoch - 3ms/step
# Epoch 29/100
# 156/156 - 1s - loss: 0.0050 - 576ms/epoch - 4ms/step
# Epoch 30/100
# 156/156 - 1s - loss: 0.0047 - 532ms/epoch - 3ms/step
# Epoch 31/100
# 156/156 - 1s - loss: 0.0049 - 537ms/epoch - 3ms/step
# Epoch 32/100
# 156/156 - 1s - loss: 0.0048 - 536ms/epoch - 3ms/step
# Epoch 33/100
# 156/156 - 1s - loss: 0.0049 - 629ms/epoch - 4ms/step
# Epoch 34/100
# 156/156 - 1s - loss: 0.0044 - 543ms/epoch - 3ms/step
# Epoch 35/100
# 156/156 - 0s - loss: 0.0046 - 495ms/epoch - 3ms/step
# Epoch 36/100
# 156/156 - 0s - loss: 0.0047 - 461ms/epoch - 3ms/step
# Epoch 37/100
# 156/156 - 1s - loss: 0.0046 - 514ms/epoch - 3ms/step
# Epoch 38/100
# 156/156 - 0s - loss: 0.0046 - 462ms/epoch - 3ms/step
# Epoch 39/100
# 156/156 - 0s - loss: 0.0047 - 443ms/epoch - 3ms/step
# Epoch 40/100
# 156/156 - 0s - loss: 0.0045 - 451ms/epoch - 3ms/step
# Epoch 41/100
# 156/156 - 1s - loss: 0.0045 - 504ms/epoch - 3ms/step
# Epoch 42/100
# 156/156 - 0s - loss: 0.0044 - 476ms/epoch - 3ms/step
# Epoch 43/100
# 156/156 - 0s - loss: 0.0045 - 467ms/epoch - 3ms/step
# Epoch 44/100
# 156/156 - 1s - loss: 0.0044 - 553ms/epoch - 4ms/step
# Epoch 45/100
# 156/156 - 1s - loss: 0.0043 - 565ms/epoch - 4ms/step
# Epoch 46/100
# 156/156 - 0s - loss: 0.0043 - 329ms/epoch - 2ms/step
# Epoch 47/100
# 156/156 - 0s - loss: 0.0043 - 365ms/epoch - 2ms/step
# Epoch 48/100
# 156/156 - 0s - loss: 0.0043 - 313ms/epoch - 2ms/step
# Epoch 49/100
# 156/156 - 0s - loss: 0.0043 - 376ms/epoch - 2ms/step
# Epoch 50/100
# 156/156 - 0s - loss: 0.0042 - 363ms/epoch - 2ms/step
# Epoch 51/100
# 156/156 - 1s - loss: 0.0043 - 503ms/epoch - 3ms/step
# Epoch 52/100
# 156/156 - 0s - loss: 0.0042 - 375ms/epoch - 2ms/step
# Epoch 53/100
# 156/156 - 0s - loss: 0.0043 - 344ms/epoch - 2ms/step
# Epoch 54/100
# 156/156 - 0s - loss: 0.0043 - 388ms/epoch - 2ms/step
# Epoch 55/100
# 156/156 - 0s - loss: 0.0041 - 365ms/epoch - 2ms/step
# Epoch 56/100
# 156/156 - 0s - loss: 0.0042 - 420ms/epoch - 3ms/step
# Epoch 57/100
# 156/156 - 0s - loss: 0.0042 - 441ms/epoch - 3ms/step
# Epoch 58/100
# 156/156 - 1s - loss: 0.0042 - 637ms/epoch - 4ms/step
# Epoch 59/100
# 156/156 - 0s - loss: 0.0041 - 380ms/epoch - 2ms/step
# Epoch 60/100
# 156/156 - 1s - loss: 0.0041 - 581ms/epoch - 4ms/step
# Epoch 61/100
# 156/156 - 0s - loss: 0.0041 - 456ms/epoch - 3ms/step
# Epoch 62/100
# 156/156 - 0s - loss: 0.0039 - 431ms/epoch - 3ms/step
# Epoch 63/100
# 156/156 - 0s - loss: 0.0042 - 359ms/epoch - 2ms/step
# Epoch 64/100
# 156/156 - 0s - loss: 0.0040 - 424ms/epoch - 3ms/step
# Epoch 65/100
# 156/156 - 0s - loss: 0.0041 - 309ms/epoch - 2ms/step
# Epoch 66/100
# 156/156 - 0s - loss: 0.0040 - 391ms/epoch - 3ms/step
# Epoch 67/100
# 156/156 - 0s - loss: 0.0041 - 376ms/epoch - 2ms/step
# Epoch 68/100
# 156/156 - 0s - loss: 0.0040 - 382ms/epoch - 2ms/step
# Epoch 69/100
# 156/156 - 0s - loss: 0.0041 - 412ms/epoch - 3ms/step
# Epoch 70/100
# 156/156 - 1s - loss: 0.0040 - 506ms/epoch - 3ms/step
# Epoch 71/100
# 156/156 - 0s - loss: 0.0040 - 438ms/epoch - 3ms/step
# Epoch 72/100
# 156/156 - 0s - loss: 0.0040 - 403ms/epoch - 3ms/step
# Epoch 73/100
# 156/156 - 0s - loss: 0.0040 - 499ms/epoch - 3ms/step
# Epoch 74/100
# 156/156 - 0s - loss: 0.0039 - 418ms/epoch - 3ms/step
# Epoch 75/100
# 156/156 - 1s - loss: 0.0040 - 502ms/epoch - 3ms/step
# Epoch 76/100
# 156/156 - 1s - loss: 0.0041 - 547ms/epoch - 4ms/step
# Epoch 77/100
# 156/156 - 1s - loss: 0.0040 - 530ms/epoch - 3ms/step
# Epoch 78/100
# 156/156 - 1s - loss: 0.0040 - 547ms/epoch - 4ms/step
# Epoch 79/100
# 156/156 - 0s - loss: 0.0039 - 450ms/epoch - 3ms/step
# Epoch 80/100
# 156/156 - 1s - loss: 0.0039 - 505ms/epoch - 3ms/step
# Epoch 81/100
# 156/156 - 1s - loss: 0.0039 - 571ms/epoch - 4ms/step
# Epoch 82/100
# 156/156 - 1s - loss: 0.0039 - 549ms/epoch - 4ms/step
# Epoch 83/100
# 156/156 - 0s - loss: 0.0041 - 489ms/epoch - 3ms/step
# Epoch 84/100
# 156/156 - 1s - loss: 0.0038 - 562ms/epoch - 4ms/step
# Epoch 85/100
# 156/156 - 1s - loss: 0.0038 - 569ms/epoch - 4ms/step
# Epoch 86/100
# 156/156 - 0s - loss: 0.0039 - 369ms/epoch - 2ms/step
# Epoch 87/100
# 156/156 - 0s - loss: 0.0039 - 335ms/epoch - 2ms/step
# Epoch 88/100
# 156/156 - 0s - loss: 0.0039 - 340ms/epoch - 2ms/step
# Epoch 89/100
# 156/156 - 0s - loss: 0.0040 - 335ms/epoch - 2ms/step
# Epoch 90/100
# 156/156 - 0s - loss: 0.0038 - 276ms/epoch - 2ms/step
# Epoch 91/100
# 156/156 - 0s - loss: 0.0039 - 423ms/epoch - 3ms/step
# Epoch 92/100
# 156/156 - 0s - loss: 0.0039 - 461ms/epoch - 3ms/step
# Epoch 93/100
# 156/156 - 0s - loss: 0.0038 - 455ms/epoch - 3ms/step
# Epoch 94/100
# 156/156 - 0s - loss: 0.0042 - 498ms/epoch - 3ms/step
# Epoch 95/100
# 156/156 - 0s - loss: 0.0038 - 351ms/epoch - 2ms/step
# Epoch 96/100
# 156/156 - 1s - loss: 0.0039 - 549ms/epoch - 4ms/step
# Epoch 97/100
# 156/156 - 0s - loss: 0.0038 - 484ms/epoch - 3ms/step
# Epoch 98/100
# 156/156 - 0s - loss: 0.0038 - 465ms/epoch - 3ms/step
# Epoch 99/100
# 156/156 - 1s - loss: 0.0039 - 550ms/epoch - 4ms/step
# Epoch 100/100
# 156/156 - 1s - loss: 0.0038 - 523ms/epoch - 3ms/step
# 2/2 [==============================] - 1s 8ms/step
# Mean Absolute Error (MAE): 0.41620409488677934

# %%
# Plot hasil prediksi
plt.plot(test_y, label='Data Saham Asli')
plt.plot(predicted, label='Prediksi Saham')
plt.legend()
plt.title('Prediksi Saham Data INDY.csv') #sesuaikan dengan dataset
plt.show()
